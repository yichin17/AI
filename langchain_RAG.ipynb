# %% [markdown]
# <a href="https://colab.research.google.com/github/yichin17/AI/blob/main/langchain_RAG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langchain
# !pip install openai
# !pip install langchain-openai
# !pip install unstructured
# !pip install chromadb
# !pip install tiktoken
# !pip install tabulate
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 973.7/973.7 kB 5.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 308.5/308.5 kB 31.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.4/121.4 kB 4.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 6.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 8.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.5/142.5 kB 19.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.0
#     Uninstalling packaging-24.0:
#       Successfully uninstalled packaging-24.0
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 320.6/320.6 kB 3.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 16.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 10.9 MB/s eta 0:00:00
# ...

# %%
# 導入 ColabSecrets 用戶資料模組
from google.colab import userdata

# 設置 OpenAI API key
import os
os.environ["OPENAI_API_KEY"] = userdata.get('OPENAI_API_KEY')
# Out:
# ---------------------------------------------------------------------------
# SecretNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-6a94cb936a52> in <cell line: 6>()
#       4 # 設置 OpenAI API key
#       5 import os
# ----> 6 os.environ["OPENAI_API_KEY"] = userdata.get('OPENAI_API_KEY')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/userdata.py in get(key)
#      51     )
#      52   if not resp.get('exists', False):
# ---> 53     raise SecretNotFoundError(key)
#      54   if not resp.get('access', False):
#      55     raise NotebookAccessError(key)
#
# SecretNotFoundError: Secret OPENAI_API_KEY does not exist.

# %%
from langchain.chat_models import ChatOpenAI
llm = ChatOpenAI(
    model_name="gpt-3.5-turbo",# 設定模型
    temperature=0.3, #隨機性
    max_tokens=512,
    )
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-5837ea857792> in <cell line: 1>()
# ----> 1 from langchain.chat_models import ChatOpenAI
#       2 llm = ChatOpenAI(
#       3     model_name="gpt-3.5-turbo",# 設定模型
#       4     temperature=0.3, #隨機性
#       5     max_tokens=512,
#
# /usr/local/lib/python3.10/dist-packages/langchain/chat_models/__init__.py in __getattr__(name)
#      25
#      26 def __getattr__(name: str) -> None:
# ---> 27     from langchain_community import chat_models
#      28
#      29     # If not in interactive env, raise warning.
#
# ModuleNotFoundError: No module named 'langchain_community'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# ...
